# %%
import math
publication=[]
rating=[]
reviewsS=[]
reviewsO=[]
reviews=[]
distance=[]
publYrS=[]
ratingS=[]
publYrO=[]
page=[]
pagesO=[]
pagesS=[]
ratingO=[]
titles=[]
def getSimilarBooks(title):
    import numpy as np
    import pandas as pd
    import requests
    import xmltodict
    import pprint
    import json
    url=' https://www.goodreads.com/book/title.xml'
    parameters={"key":' laszLDheUrLhOPhB43g',"title":title}
    result = requests.get(url,params=parameters)
    my_dict = xmltodict.parse(result.content)
    x=my_dict['GoodreadsResponse']['book']
    if 'id' in x:
        idb=x['id']
    url='https://www.goodreads.com/book/show.xml'
    parameters={"key":' laszLDheUrLhOPhB43g',"id":idb}
    result = requests.get(url,params=parameters)
    my_dict = xmltodict.parse(result.content)
    x=my_dict['GoodreadsResponse']['book']
    tempt=my_dict['GoodreadsResponse']['book']['title']
    tempi=my_dict['GoodreadsResponse']['book']['id']
    if 'publication_year' in x:
        publicationYear=my_dict['GoodreadsResponse']['book']['publication_year']
    if 'average_rating' in x:
        ratingsAvg=my_dict['GoodreadsResponse']['book']['average_rating']
    if 'num_pages' in x:
        pages=my_dict['GoodreadsResponse']['book']['num_pages']
    if 'reviews_count' in x['work']:
        review=my_dict['GoodreadsResponse']['book']['work']['reviews_count']['#text']
    if 'similar_books' in x:
        ans=my_dict['GoodreadsResponse']['book']['similar_books']['book']
        cnt=0;
        for j in ans:
            flag=0
            if cnt<5:
                idb1=j['id']
                title=j['title']
                df=pd.read_csv('reject.csv')
                for i,row in df.iterrows():
                    if row["names"]==title:
                        flag=1
                        break
                for i in range(len(titles)):
                    if titles[i]==title:
                        flag=1
                        break
                if flag==0:
                    print('title is : {}'.format(j['title']))
                    titles.append(j['title'])
                    if j['publication_year'] != None:
                        print('publication_year : {}'.format(j['publication_year']))
                        publYrS.append(int(j['publication_year']))
                    else:
                        publYrS.append(0)               
                    if j['average_rating'] != None:
                        print('average_rating : {}'.format(j['average_rating']))
                        ratingS.append(float(j['average_rating']))
                    else:
                        ratingS.append(0)
                    if j['num_pages'] != None:
                        print('num_page : {}'.format(j['num_pages']))
                        pagesS.append(int(j['num_pages']))
                    else:
                        pagesS.append(0)
                    cnt=cnt+1
                    url='https://www.goodreads.com/book/show.xml'
                    parameters={"key":' laszLDheUrLhOPhB43g',"id":idb1}
                    result = requests.get(url,params=parameters)
                    my_dict = xmltodict.parse(result.content)
                    x=my_dict['GoodreadsResponse']['book']['work']
                    print('reviews_count : {}'.format(x['reviews_count']['#text']))
                    reviewsS.append(int(x['reviews_count']['#text']))

    else:
        print('no similar books exist')
        
    if publicationYear != None:
        publYrO.append(int(publicationYear))
    else:
        publYrO.append(0)
    if ratingsAvg != None:
        ratingO.append(float(ratingsAvg))
    else:
        ratingO.append(0)
    if pages != None:
        pagesO.append(int(pages))
    else:
        pagesO.append(0)
    if review != None:
        reviewsO.append(int(review))
    else:
        reviewsO.append(0)

# %%
def userChoice(title1,title2,title3):
    getSimilarBooks(title1);
    getSimilarBooks(title2);
    getSimilarBooks(title3);
    
    print(publYrS)
    print(ratingS)
    print(reviewsS)
    print(pagesS)
    print(publYrO)
    print(ratingO)
    print(reviewsO)
    print(pagesO)

# %%
userChoice("The Fellowship of the Ring (The Lord of the Rings #1)","Harry Potter and the Sorcerer's Stone","Hatchet")
# Out:
# title is : Through the Looking-Glass and What Alice Found There (Alice's Adventures in Wonderland, #2)
# publication_year : 1993
# average_rating : 4.35
# num_page : 228
# reviews_count : 26054
# title is : The Handmaid's Tale
# publication_year : 1998
# average_rating : 4.35
# num_page : 344
# reviews_count : 96643
# title is : Sherlock Holmes: The Complete Novels and Stories, Volume  #2
# publication_year : 2003
# average_rating : 4.35
# num_page : 737
# reviews_count : 4657
# title is : Anna Karenina
# publication_year : 2012
# average_rating : 4.35
# num_page : 964
# reviews_count : 85466
# title is : His Dark Materials (His Dark Materials #1-3)
# average_rating : 4.35
# num_page : 1088
# reviews_count : 57770
# title is : Speak
# publication_year : 2019
# average_rating : 4.46
# num_page : 224
# reviews_count : 79542
# title is : In the Hand of the Goddess (Song of the Lioness, #2)
# publication_year : 2005
# average_rating : 4.46
# num_page : 264
# reviews_count : 102774
# title is : Watership Down (Watership Down, #1)
# publication_year : 1975
# average_rating : 4.46
# num_page : 478
# reviews_count : 136702
# title is : Where'd You Go, Bernadette
# publication_year : 2012
# average_rating : 4.46
# num_page : 330
# reviews_count : 59214
# title is : Abhorsen (Abhorsen, #3)
# publication_year : 2003
# average_rating : 4.46
# num_page : 358
# reviews_count : 127386
# title is : The Great Fire
# publication_year : 2006
# average_rating : 3.70
# num_page : 144
# reviews_count : 4338
# title is : The Sign of the Beaver
# publication_year : 1983
# average_rating : 3.70
# num_page : 148
# reviews_count : 41369
# title is : The Cay (The Cay, #1)
# publication_year : 2003
# average_rating : 3.70
# num_page : 156
# reviews_count : 40991
# title is : Homesick: My Own Story
# publication_year : 2007
# average_rating : 3.70
# num_page : 176
# reviews_count : 4520
# title is : The Secret of the Indian
# publication_year : 2003
# average_rating : 3.70
# num_page : 145
# reviews_count : 12406
# [1993, 1998, 2003, 2012, 0, 2019, 2005, 1975, 2012, 2003, 2006, 1983, 2003, 2007, 2003]
# [4.35, 4.35, 4.35, 4.35, 4.35, 4.46, 4.46, 4.46, 4.46, 4.46, 3.7, 3.7, 3.7, 3.7, 3.7]
# [26054, 96643, 4657, 85466, 57770, 79542, 102774, 136702, 59214, 127386, 4338, 41369, 40991, 4520, 12406]
# [228, 344, 737, 964, 1088, 224, 264, 478, 330, 358, 144, 148, 156, 176, 145]
# [2003, 1997, 2000]
# [4.35, 4.46, 3.7]
# [2647314, 6656319, 358283]
# [398, 320, 208]

# %%
def distanceCalculation():
    x=len(publYrS)
    x1=publYrO[0]
    x2=publYrO[1]
    x3=publYrO[2]
    for i in range(x):
        dist=math.sqrt((publYrS[i]-x1)**2+(publYrS[i]-x2)**2+(publYrS[i]-x3)**2)
        publication.append(dist)
    y=len(ratingS)
    y1=ratingO[0]
    y2=ratingO[1]
    y3=ratingO[2]
    for i in range(y):
        dist=math.sqrt((ratingS[i]-y1)**2+(ratingS[i]-y2)**2+(ratingS[i]-y3)**2)
        rating.append(dist)   
    z=len(pagesS)
    z1=pagesO[0]
    z2=pagesO[1]
    z3=pagesO[2]
    for i in range(z):
        dist=math.sqrt((pagesS[i]-z1)**2+(pagesS[i]-z2)**2+(pagesS[i]-z3)**2)
        page.append(dist)
    w=len(reviewsS)
    w1=reviewsO[0]
    w2=reviewsO[1]
    w3=reviewsO[2]
    for i in range(w):
        dist=math.sqrt((reviewsS[i]-w1)**2+(reviewsS[i]-w2)**2+(reviewsS[i]-w3)**2)
        reviews.append(dist)

# %%
distanceCalculation()

# %%
yr=15
rate=4
pg=8
rv=6
x=len(rating)
for i in range(x):
    dist=rating[i]*rate+publication[i]*yr+page[i]*pg+reviews[i]*rv
    distance.append(dist)

for i in range(1,x):
    data=distance[i]
    book=titles[i]
    j=i-1
    while data<distance[j] and j>=0:
        distance[j+1]=distance[j]
        titles[j+1]=titles[j]
        j=j-1
    distance[j+1]=data
    titles[j+1]=book
    
print(distance)
print(titles)
# Out:
# [41616827.07857917, 41863658.23056918, 41916786.41844398, 41964774.25405722, 42111946.66431631, 42231154.649569355, 42265018.48060174, 42321015.310434274, 42490853.32923361, 42603687.86595315, 42606226.755654655, 42731850.1060798, 42836456.310165465, 42899834.56127173, 42901616.42361513]
# ['A Wrinkle in Time (Time Quintet, #1)', 'Watership Down (Watership Down, #1)', 'Abhorsen (Abhorsen, #3)', 'Harry Potter and the Deathly Hallows (Harry Potter, #7)', 'In the Hand of the Goddess (Song of the Lioness, #2)', "The Handmaid's Tale", 'Lord of the Flies', 'Speak', "Where'd You Go, Bernadette", 'The Sign of the Beaver', 'The Cay (The Cay, #1)', "Through the Looking-Glass and What Alice Found There (Alice's Adventures in Wonderland, #2)", 'The Secret of the Indian', 'Homesick: My Own Story', 'The Great Fire']
